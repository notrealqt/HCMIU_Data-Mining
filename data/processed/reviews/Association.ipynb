# %%
import pandas as pd
import os

review_data = pd.DataFrame()

for i in range(1, 10):
    file_path = os.path.join(f'review\cleaned_review\steam_game_review_encoded_part_{i}.csv')

    if os.path.exists(file_path):
        print(f'File found: {os.path.abspath(file_path)}')
        part_data = pd.read_csv(file_path)
        review_data = pd.concat([review_data, part_data], ignore_index=True)
    else:
        print(f'File not found: {os.path.abspath(file_path)}')

if review_data.empty:
    print("Error: No game data loaded.")
else:
    print(f"Successfully loaded {len(review_data)} rows.")
# Out:
# File not found: d:\data-mining-hcmiu\review\cleaned_review\review\cleaned_review\steam_game_review_encoded_part_1.csv
# File not found: d:\data-mining-hcmiu\review\cleaned_review\review\cleaned_review\steam_game_review_encoded_part_2.csv
# File not found: d:\data-mining-hcmiu\review\cleaned_review\review\cleaned_review\steam_game_review_encoded_part_3.csv
# File not found: d:\data-mining-hcmiu\review\cleaned_review\review\cleaned_review\steam_game_review_encoded_part_4.csv
# File not found: d:\data-mining-hcmiu\review\cleaned_review\review\cleaned_review\steam_game_review_encoded_part_5.csv
# File not found: d:\data-mining-hcmiu\review\cleaned_review\review\cleaned_review\steam_game_review_encoded_part_6.csv
# File not found: d:\data-mining-hcmiu\review\cleaned_review\review\cleaned_review\steam_game_review_encoded_part_7.csv
# File not found: d:\data-mining-hcmiu\review\cleaned_review\review\cleaned_review\steam_game_review_encoded_part_8.csv
# File not found: d:\data-mining-hcmiu\review\cleaned_review\review\cleaned_review\steam_game_review_encoded_part_9.csv
# Error: No game data loaded.
